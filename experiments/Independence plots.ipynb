# %%
import pickle
import numpy as np
import pandas as pd
import os
from MINE.gtm import GTM
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 20, 15
from tqdm import tqdm
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
from matplotlib.legend_handler import HandlerLine2D

import warnings
warnings.filterwarnings('ignore')

SMALL_SIZE = 10
MEDIUM_SIZE = 20
BIGGER_SIZE = 30

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
with open('clean_results/independence.pkl', 'rb') as fd:
    d = pickle.load(fd)
    
d.k = d.k.apply(lambda x: f'k={x}')

# %%
d['method_full'] = d.loc[:, ['method', 'k']].apply(lambda x: ' '.join(x), axis=1)

# %%
d
# Out:
#       iter         method     k   c        mi         method_full
# 0        0       original   k=2   1  0.002601        original k=2
# 1        0       original  k=10   1  0.001904       original k=10
# 2        0      bootstrap   k=2   1  0.017310       bootstrap k=2
# 3        0      bootstrap  k=10   1  0.029027      bootstrap k=10
# 4        0  bootstrap_avg   k=2   1 -0.002017   bootstrap_avg k=2
# ...    ...            ...   ...  ..       ...                 ...
# 5995    99       original  k=10  10  0.005210       original k=10
# 5996    99      bootstrap   k=2  10  0.000251       bootstrap k=2
# 5997    99      bootstrap  k=10  10  0.024368      bootstrap k=10
# 5998    99  bootstrap_avg   k=2  10  0.001542   bootstrap_avg k=2
# 5999    99  bootstrap_avg  k=10  10 -0.004012  bootstrap_avg k=10
#
# [6000 rows x 6 columns]

# %%
sns.lineplot(x='c', y='mi', hue='method_full', data=d)
# Out:
# <AxesSubplot:xlabel='c', ylabel='mi'>
